# %%
# !git clone https://github.com/Maxization/MedSegDiff.git
# Out:
# Cloning into 'MedSegDiff'...
# remote: Enumerating objects: 3543, done.
# remote: Counting objects: 100% (311/311), done.
# remote: Compressing objects: 100% (119/119), done.
# remote: Total 3543 (delta 262), reused 205 (delta 190), pack-reused 3232
# Receiving objects: 100% (3543/3543), 131.69 MiB | 32.23 MiB/s, done.
# Resolving deltas: 100% (1772/1772), done.
# Updating files: 100% (2797/2797), done.

# %%
# %cd ~/MedSegDiff
# Out:
# /home/jupyter/MedSegDiff

# %%
pip install -r requirement.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 90.5 MB/s eta 0:00:00:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 20.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 12.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 77.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 92.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 101.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 kB 65.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 19.1 MB/s eta 0:00:00
# ...

# %%
get_ipython().system_raw('/opt/conda/bin/python -m pip install visdom')
get_ipython().system_raw('/opt/conda/bin/python -m visdom.server -port 8850 >> visdomlog.txt 2>&1 &')
get_ipython().system_raw('lt --port 8850 >> url.txt 2>&1 &')

# %%
# !python scripts/segmentation_train.py --resume_checkpoint ./output/savedmodel110000.pt --data_name MRI --dpm_solver True --data_dir ./data/mri/train --out_dir ./output --image_size 256 --num_channels 128 --class_cond False --num_res_blocks 2 --num_heads 1 --learn_sigma True --use_scale_shift_norm False --attention_resolutions 16 --diffusion_steps 100 --noise_schedule linear --rescale_learned_sigmas False --rescale_timesteps False --lr 1e-4 --batch_size 4
# Out:
# Setting up a new session...
# Logging to ./output
# creating data loader...
# creating model and diffusion...
# training...
# resume model
# loading model from checkpoint: ./output/savedmodel110000.pt...
# /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:1967: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# ---------------------------
# | grad_norm    | 0.239    |
# | loss         | 0.00129  |
# | loss_cal     | 0.00124  |
# | loss_cal_q0  | 0.00129  |
# | loss_cal_q1  | 0.00178  |
# | loss_cal_q2  | 0.000592 |
# | loss_diff    | 0.001    |
# | loss_diff_q0 | 0.00157  |
# | loss_diff_q1 | 0.000686 |
# | loss_diff_q2 | 0.000185 |
# | loss_q0      | 0.00211  |
# | loss_q1      | 0.000742 |
# | loss_q2      | 0.000205 |
# | param_norm   | 307      |
# | samples      | 4.4e+05  |
# | step         | 1.1e+05  |
# | vb           | 0.000288 |
# ...

# %%
# !python scripts/segmentation_sample.py --data_name MRI --data_dir ./data/mri/test --out_dir ./results220000_gray --model_path ./output/savedmodel155000.pt --image_size 256 --num_channels 128 --class_cond False --num_res_blocks 2 --num_heads 1 --learn_sigma True --use_scale_shift_norm False --attention_resolutions 16 --diffusion_steps 100 --noise_schedule linear --rescale_learned_sigmas False --rescale_timesteps False --num_ensemble 5
# Out:
# Logging to ./results220000_gray
# creating model and diffusion...
# TCGA_HT_7884_19980913_12
# sampling...
# no dpm-solver
# /opt/conda/lib/python3.10/site-packages/torch/nn/functional.py:1967: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# time for 1 sample 8637.4951171875
# /home/jupyter/MedSegDiff/scripts/segmentation_sample.py:137: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   co = th.tensor(cal_out)
# no dpm-solver
# time for 1 sample 7497.54541015625
# no dpm-solver
# time for 1 sample 7525.93505859375
# no dpm-solver
# time for 1 sample 7557.39794921875
# no dpm-solver
# time for 1 sample 7511.33642578125
# TCGA_HT_A61B_19991127_45
# sampling...
# no dpm-solver
# time for 1 sample 7525.20361328125
# ...
